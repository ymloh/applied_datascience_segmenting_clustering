# %% [markdown]
# Applied Data Science Capstone
# ================================
# ### Assignment, Week 3

# %% [markdown]
#   ***

# %% [markdown]
# # **Part 1**

# %% [markdown]
# Imports

# %%
# !pip install bs4
# !pip install geocoder
import urllib.request as req
from bs4 import BeautifulSoup as BS
from time import sleep
import pandas as pd
from os import getenv
import json

# %% [markdown]
#
# Scraping data from wikipedia

# %%
url = 'https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M'
wiki_page = req.urlopen(url)
wiki_soup = BS(wiki_page, 'html.parser')
data_table = wiki_soup.find('table', class_='wikitable sortable')

headers = [x.find(text=True).rstrip() for x in data_table.findAll('th')]

df = pd.DataFrame(columns=headers)

for row in data_table.findAll('tr'):
    cells = [x.find(text=True).rstrip() for x in row.findAll('td')]
    if len(cells) != 0:
        df = df.append(pd.DataFrame([cells], columns=headers), ignore_index=True)

df.head()
# Out:
#   Postal Code           Borough               Neighborhood
# 0         M1A      Not assigned
# 1         M2A      Not assigned
# 2         M3A        North York                  Parkwoods
# 3         M4A        North York           Victoria Village
# 4         M5A  Downtown Toronto  Regent Park, Harbourfront

# %% [markdown]
# Clean up dataframe

# %%
df_clean = df[df['Borough'] != 'Not assigned']

df_clean = df_clean.groupby(['Postal Code']).aggregate(lambda x: ', '.join(x)).reset_index()

print('Cleaned DataFrame shape: ', df_clean.shape)
# Out:
# Cleaned DataFrame shape:  (103, 3)

# %%
df_clean.head()
# Out:
#   Postal Code      Borough                            Neighborhood
# 0         M1B  Scarborough                          Malvern, Rouge
# 1         M1C  Scarborough  Rouge Hill, Port Union, Highland Creek
# 2         M1E  Scarborough       Guildwood, Morningside, West Hill
# 3         M1G  Scarborough                                  Woburn
# 4         M1H  Scarborough                               Cedarbrae

# %% [markdown]
# ***
# # **Part 2**

# %%
df_coords = pd.read_csv('Geospatial_Coordinates.csv')
df_geo = pd.merge(df_clean, df_coords, on=['Postal Code', 'Postal Code'])

df_geo.head()
# Out:
#   Postal Code      Borough                            Neighborhood   Latitude  \
# 0         M1B  Scarborough                          Malvern, Rouge  43.806686
# 1         M1C  Scarborough  Rouge Hill, Port Union, Highland Creek  43.784535
# 2         M1E  Scarborough       Guildwood, Morningside, West Hill  43.763573
# 3         M1G  Scarborough                                  Woburn  43.770992
# 4         M1H  Scarborough                               Cedarbrae  43.773136
#
#    Longitude
# 0 -79.194353
# 1 -79.160497
# 2 -79.188711
# 3 -79.216917
# 4 -79.239476

# %% [markdown]
# ***
# # **Part 3**

# %%
from geopy.geocoders import Nominatim
import folium

address = "Toronto, ON"
loc = Nominatim(user_agent="toronto_explorer").geocode(address)

print('Geographic coordinates of Toronto, ON, Canada are {}, {}'.format(loc.latitude, loc.longitude))

map_toronto = folium.Map(location=[loc.latitude, loc.longitude], zoom_start=11)

# look at boroughs that have 'Toronto' in their name
df_geo = df_geo[df_geo['Borough'].str.contains('Toronto')].reset_index(drop=True)

for i, row in df_geo.iterrows():
    label = '{}, {}'.format(row['Neighborhood'], row['Borough'])
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [row['Latitude'], row['Longitude']],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False
    ).add_to(map_toronto)

map_toronto
# Out:
# Geographic coordinates of Toronto, ON, Canada are 43.6534817, -79.3839347
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# **Set up FourSquare params.**

# %%
from pandas import json_normalize
from os import path, mkdir

CLIENT_ID = getenv('FOURSQR_ID')
CLIENT_SECRET = getenv('FOURSQR_SECRET')
VERSION = '20180605'

# for local storage (remove directory 'venue_data' to reload everything from foursquare)
DATA_PATH = 'venue_data'
if not path.exists(DATA_PATH):
    mkdir(DATA_PATH)

LIMIT = 500
RADIUS = 500
CATEGORY_ID = '4d4b7105d754a06374d81259' # Food

# %% [markdown]
# **Retrieve top-level venue categories.**

# %%
cats_local = 'categories.json'
cats = None

if path.isfile(cats_local):
    print('Found local categories json. Loading...')
    with open(cats_local, 'r') as jsonfile:
        cats = json.load(jsonfile)
        print('Done!')
else:
    print('Local categories json not found. Loading from FourSquare...')
    cats_url = 'https://api.foursquare.com/v2/venues/categories?client_id={}&client_secret={}&v={}'.format(
        CLIENT_ID, CLIENT_SECRET, VERSION)
    results = json.load(req.urlopen(cats_url))
    cats = results['response']['categories']
    print('Writing loaded categories to local json...')
    with open(cats_local, 'w') as jsonfile:
        json.dump(cats, jsonfile)
        print('Done!')

cats_id_list = []
for cat in cats:
    cats_id_list.append(cat['id'])
# Out:
# Found local categories json. Loading...
# Done!

# %% [markdown]
# **Retrieving venues within 500m of postal code geolocations.**

# %%
df_venues = pd.DataFrame()

for i, row in df_geo.iterrows():
    for cat in cats:
        df = None
        # check for locally stored data
        filepath = path.join(DATA_PATH, '-'.join([row['Postal Code'], cat['shortName']]))
        if path.isfile(filepath):
            # locally stored data found
            print('Found local data for {}'.format('-'.join([row['Postal Code'], cat['shortName']])))
            df = pd.read_pickle(filepath, compression='gzip')
        else:
            # retrieve data from foursquare, then store locally
            print('Retrieving foursquare data for {}'.format('-'.join([row['Postal Code'], cat['shortName']])))
            url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}&categoryId={}'.format(
                CLIENT_ID, CLIENT_SECRET, VERSION, df_geo.loc[i, 'Latitude'], df_geo.loc[i, 'Longitude'], RADIUS, LIMIT, cat['id'])

            results = json.load(req.urlopen(url))
            venues = results['response']['venues']

            df = json_normalize(venues)

            print('Storing retrieved data locally to {}...'.format(filepath))
            df.to_pickle(filepath, compression='gzip')

        if not df.empty:
            df = df[['name', 'location.lat', 'location.lng', 'categories']]
            df.columns = ['name', 'lat', 'lng', 'categories']
            df.insert(0, 'main category', cat['shortName'])
            df.insert(0, 'postcode', row['Postal Code'])
            df.insert(0, 'neighborhoods', row['Neighborhood'])
            print('Postal Code [{}] category [{}] venues dataframe shape: {}'.format(row['Postal Code'], cat['shortName'], df.shape))
            df_venues = df_venues.append(df)

df_venues = df_venues.reset_index(drop=True)
print('Done loading venues!')
print(df_venues.shape)
df_venues.head()
# Out:
# Found local data for M4E-Arts & Entertainment
# Postal Code [M4E] category [Arts & Entertainment] venues dataframe shape: (5, 7)
# Found local data for M4E-College & Education
# Postal Code [M4E] category [College & Education] venues dataframe shape: (4, 7)
# Found local data for M4E-Event
# Found local data for M4E-Food
# Postal Code [M4E] category [Food] venues dataframe shape: (38, 7)
# Found local data for M4E-Nightlife
# Postal Code [M4E] category [Nightlife] venues dataframe shape: (7, 7)
# Found local data for M4E-Outdoors & Recreation
# Postal Code [M4E] category [Outdoors & Recreation] venues dataframe shape: (19, 7)
# Found local data for M4E-Professional
# Postal Code [M4E] category [Professional] venues dataframe shape: (27, 7)
# Found local data for M4E-Residence
# Postal Code [M4E] category [Residence] venues dataframe shape: (5, 7)
# Found local data for M4E-Shops
# Postal Code [M4E] category [Shops] venues dataframe shape: (39, 7)
# Found local data for M4E-Travel
# Postal Code [M4E] category [Travel] venues dataframe shape: (4, 7)
# Found local data for M4K-Arts & Entertainment
# Postal Code [M4K] category [Arts & Entertainment] venues dataframe shape: (19, 7)
# Found local data for M4K-College & Education
# Postal Code [M4K] category [College & Education] venues dataframe shape: (3, 7)
# Found local data for M4K-Event
# Found local data for M4K-Food
# Postal Code [M4K] category [Food] venues dataframe shape: (49, 7)
# Found local data for M4K-Nightlife
# Postal Code [M4K] category [Nightlife] venues dataframe shape: (31, 7)
# Found local data for M4K-Outdoors & Recreation
# Postal Code [M4K] category [Outdoors & Recreation] venues dataframe shape: (43, 7)
# Found local data for M4K-Professional
# Postal Code [M4K] category [Professional] venues dataframe shape: (40, 7)
# Found local data for M4K-Residence
# Postal Code [M4K] category [Residence] venues dataframe shape: (7, 7)
# Found local data for M4K-Shops
# Postal Code [M4K] category [Shops] venues dataframe shape: (42, 7)
# Found local data for M4K-Travel
# Postal Code [M4K] category [Travel] venues dataframe shape: (11, 7)
# Found local data for M4L-Arts & Entertainment
# Postal Code [M4L] category [Arts & Entertainment] venues dataframe shape: (17, 7)
# Found local data for M4L-College & Education
# Postal Code [M4L] category [College & Education] venues dataframe shape: (2, 7)
# Found local data for M4L-Event
# Found local data for M4L-Food
# Postal Code [M4L] category [Food] venues dataframe shape: (46, 7)
# Found local data for M4L-Nightlife
# Postal Code [M4L] category [Nightlife] venues dataframe shape: (11, 7)
# Found local data for M4L-Outdoors & Recreation
# Postal Code [M4L] category [Outdoors & Recreation] venues dataframe shape: (21, 7)
# Found local data for M4L-Professional
# Postal Code [M4L] category [Professional] venues dataframe shape: (30, 7)
# Found local data for M4L-Residence
# Postal Code [M4L] category [Residence] venues dataframe shape: (3, 7)
# Found local data for M4L-Shops
# Postal Code [M4L] category [Shops] venues dataframe shape: (46, 7)
# Found local data for M4L-Travel
# Postal Code [M4L] category [Travel] venues dataframe shape: (12, 7)
# Found local data for M4M-Arts & Entertainment
# Postal Code [M4M] category [Arts & Entertainment] venues dataframe shape: (32, 7)
# Found local data for M4M-College & Education
# Postal Code [M4M] category [College & Education] venues dataframe shape: (1, 7)
# Found local data for M4M-Event
# Postal Code [M4M] category [Event] venues dataframe shape: (1, 7)
# Found local data for M4M-Food
# Postal Code [M4M] category [Food] venues dataframe shape: (49, 7)
# Found local data for M4M-Nightlife
# Postal Code [M4M] category [Nightlife] venues dataframe shape: (25, 7)
# Found local data for M4M-Outdoors & Recreation
# Postal Code [M4M] category [Outdoors & Recreation] venues dataframe shape: (42, 7)
# Found local data for M4M-Professional
# Postal Code [M4M] category [Professional] venues dataframe shape: (48, 7)
# Found local data for M4M-Residence
# Postal Code [M4M] category [Residence] venues dataframe shape: (6, 7)
# Found local data for M4M-Shops
# Postal Code [M4M] category [Shops] venues dataframe shape: (41, 7)
# Found local data for M4M-Travel
# Postal Code [M4M] category [Travel] venues dataframe shape: (20, 7)
# Found local data for M4N-Arts & Entertainment
# Postal Code [M4N] category [Arts & Entertainment] venues dataframe shape: (3, 7)
# Found local data for M4N-College & Education
# Postal Code [M4N] category [College & Education] venues dataframe shape: (4, 7)
# Found local data for M4N-Event
# Found local data for M4N-Food
# Postal Code [M4N] category [Food] venues dataframe shape: (1, 7)
# Found local data for M4N-Nightlife
# Found local data for M4N-Outdoors & Recreation
# Postal Code [M4N] category [Outdoors & Recreation] venues dataframe shape: (4, 7)
# Found local data for M4N-Professional
# Postal Code [M4N] category [Professional] venues dataframe shape: (8, 7)
# Found local data for M4N-Residence
# Postal Code [M4N] category [Residence] venues dataframe shape: (1, 7)
# Found local data for M4N-Shops
# Postal Code [M4N] category [Shops] venues dataframe shape: (4, 7)
# Found local data for M4N-Travel
# Postal Code [M4N] category [Travel] venues dataframe shape: (1, 7)
# Found local data for M4P-Arts & Entertainment
# Postal Code [M4P] category [Arts & Entertainment] venues dataframe shape: (9, 7)
# Found local data for M4P-College & Education
# Postal Code [M4P] category [College & Education] venues dataframe shape: (2, 7)
# Found local data for M4P-Event
# Found local data for M4P-Food
# Postal Code [M4P] category [Food] venues dataframe shape: (21, 7)
# Found local data for M4P-Nightlife
# Postal Code [M4P] category [Nightlife] venues dataframe shape: (10, 7)
# Found local data for M4P-Outdoors & Recreation
# Postal Code [M4P] category [Outdoors & Recreation] venues dataframe shape: (28, 7)
# Found local data for M4P-Professional
# Postal Code [M4P] category [Professional] venues dataframe shape: (39, 7)
# Found local data for M4P-Residence
# Postal Code [M4P] category [Residence] venues dataframe shape: (46, 7)
# Found local data for M4P-Shops
# Postal Code [M4P] category [Shops] venues dataframe shape: (30, 7)
# Found local data for M4P-Travel
# Postal Code [M4P] category [Travel] venues dataframe shape: (6, 7)
# Found local data for M4R-Arts & Entertainment
# Postal Code [M4R] category [Arts & Entertainment] venues dataframe shape: (6, 7)
# Found local data for M4R-College & Education
# Postal Code [M4R] category [College & Education] venues dataframe shape: (4, 7)
# Found local data for M4R-Event
# Found local data for M4R-Food
# Postal Code [M4R] category [Food] venues dataframe shape: (28, 7)
# Found local data for M4R-Nightlife
# Postal Code [M4R] category [Nightlife] venues dataframe shape: (1, 7)
# Found local data for M4R-Outdoors & Recreation
# Postal Code [M4R] category [Outdoors & Recreation] venues dataframe shape: (8, 7)
# Found local data for M4R-Professional
# Postal Code [M4R] category [Professional] venues dataframe shape: (17, 7)
# Found local data for M4R-Residence
# Postal Code [M4R] category [Residence] venues dataframe shape: (4, 7)
# Found local data for M4R-Shops
# Postal Code [M4R] category [Shops] venues dataframe shape: (45, 7)
# Found local data for M4R-Travel
# Postal Code [M4R] category [Travel] venues dataframe shape: (5, 7)
# Found local data for M4S-Arts & Entertainment
# Postal Code [M4S] category [Arts & Entertainment] venues dataframe shape: (16, 7)
# Found local data for M4S-College & Education
# Postal Code [M4S] category [College & Education] venues dataframe shape: (10, 7)
# Found local data for M4S-Event
# Found local data for M4S-Food
# Postal Code [M4S] category [Food] venues dataframe shape: (47, 7)
# Found local data for M4S-Nightlife
# Postal Code [M4S] category [Nightlife] venues dataframe shape: (12, 7)
# Found local data for M4S-Outdoors & Recreation
# Postal Code [M4S] category [Outdoors & Recreation] venues dataframe shape: (28, 7)
# Found local data for M4S-Professional
# Postal Code [M4S] category [Professional] venues dataframe shape: (45, 7)
# Found local data for M4S-Residence
# Postal Code [M4S] category [Residence] venues dataframe shape: (18, 7)
# Found local data for M4S-Shops
# Postal Code [M4S] category [Shops] venues dataframe shape: (39, 7)
# Found local data for M4S-Travel
# Postal Code [M4S] category [Travel] venues dataframe shape: (6, 7)
# Found local data for M4T-Arts & Entertainment
# Postal Code [M4T] category [Arts & Entertainment] venues dataframe shape: (1, 7)
# Found local data for M4T-College & Education
# Postal Code [M4T] category [College & Education] venues dataframe shape: (1, 7)
# Found local data for M4T-Event
# Found local data for M4T-Food
# Postal Code [M4T] category [Food] venues dataframe shape: (5, 7)
# Found local data for M4T-Nightlife
# Found local data for M4T-Outdoors & Recreation
# Postal Code [M4T] category [Outdoors & Recreation] venues dataframe shape: (13, 7)
# Found local data for M4T-Professional
# Postal Code [M4T] category [Professional] venues dataframe shape: (10, 7)
# Found local data for M4T-Residence
# Postal Code [M4T] category [Residence] venues dataframe shape: (1, 7)
# Found local data for M4T-Shops
# Postal Code [M4T] category [Shops] venues dataframe shape: (4, 7)
# Found local data for M4T-Travel
# Postal Code [M4T] category [Travel] venues dataframe shape: (1, 7)
# Found local data for M4V-Arts & Entertainment
# Postal Code [M4V] category [Arts & Entertainment] venues dataframe shape: (11, 7)
# Found local data for M4V-College & Education
# Postal Code [M4V] category [College & Education] venues dataframe shape: (7, 7)
# Found local data for M4V-Event
# Found local data for M4V-Food
# Postal Code [M4V] category [Food] venues dataframe shape: (47, 7)
# Found local data for M4V-Nightlife
# Postal Code [M4V] category [Nightlife] venues dataframe shape: (9, 7)
# Found local data for M4V-Outdoors & Recreation
# Postal Code [M4V] category [Outdoors & Recreation] venues dataframe shape: (16, 7)
# Found local data for M4V-Professional
# Postal Code [M4V] category [Professional] venues dataframe shape: (38, 7)
# Found local data for M4V-Residence
# Postal Code [M4V] category [Residence] venues dataframe shape: (36, 7)
# Found local data for M4V-Shops
# Postal Code [M4V] category [Shops] venues dataframe shape: (34, 7)
# Found local data for M4V-Travel
# Postal Code [M4V] category [Travel] venues dataframe shape: (14, 7)
# Found local data for M4W-Arts & Entertainment
# Postal Code [M4W] category [Arts & Entertainment] venues dataframe shape: (2, 7)
# Found local data for M4W-College & Education
# Postal Code [M4W] category [College & Education] venues dataframe shape: (1, 7)
# Found local data for M4W-Event
# Found local data for M4W-Food
# Postal Code [M4W] category [Food] venues dataframe shape: (3, 7)
# Found local data for M4W-Nightlife
# Found local data for M4W-Outdoors & Recreation
# Postal Code [M4W] category [Outdoors & Recreation] venues dataframe shape: (12, 7)
# Found local data for M4W-Professional
# Postal Code [M4W] category [Professional] venues dataframe shape: (12, 7)
# Found local data for M4W-Residence
# Postal Code [M4W] category [Residence] venues dataframe shape: (6, 7)
# Found local data for M4W-Shops
# Postal Code [M4W] category [Shops] venues dataframe shape: (4, 7)
# Found local data for M4W-Travel
# Postal Code [M4W] category [Travel] venues dataframe shape: (4, 7)
# Found local data for M4X-Arts & Entertainment
# Postal Code [M4X] category [Arts & Entertainment] venues dataframe shape: (31, 7)
# Found local data for M4X-College & Education
# Postal Code [M4X] category [College & Education] venues dataframe shape: (3, 7)
# Found local data for M4X-Event
# Found local data for M4X-Food
# Postal Code [M4X] category [Food] venues dataframe shape: (47, 7)
# Found local data for M4X-Nightlife
# Postal Code [M4X] category [Nightlife] venues dataframe shape: (15, 7)
# Found local data for M4X-Outdoors & Recreation
# Postal Code [M4X] category [Outdoors & Recreation] venues dataframe shape: (32, 7)
# Found local data for M4X-Professional
# Postal Code [M4X] category [Professional] venues dataframe shape: (39, 7)
# Found local data for M4X-Residence
# Postal Code [M4X] category [Residence] venues dataframe shape: (36, 7)
# Found local data for M4X-Shops
# Postal Code [M4X] category [Shops] venues dataframe shape: (40, 7)
# Found local data for M4X-Travel
# Postal Code [M4X] category [Travel] venues dataframe shape: (19, 7)
# Found local data for M4Y-Arts & Entertainment
# Postal Code [M4Y] category [Arts & Entertainment] venues dataframe shape: (42, 7)
# Found local data for M4Y-College & Education
# Postal Code [M4Y] category [College & Education] venues dataframe shape: (44, 7)
# Found local data for M4Y-Event
# Postal Code [M4Y] category [Event] venues dataframe shape: (1, 7)
# Found local data for M4Y-Food
# Postal Code [M4Y] category [Food] venues dataframe shape: (49, 7)
# Found local data for M4Y-Nightlife
# Postal Code [M4Y] category [Nightlife] venues dataframe shape: (47, 7)
# Found local data for M4Y-Outdoors & Recreation
# Postal Code [M4Y] category [Outdoors & Recreation] venues dataframe shape: (38, 7)
# Found local data for M4Y-Professional
# Postal Code [M4Y] category [Professional] venues dataframe shape: (44, 7)
# Found local data for M4Y-Residence
# Postal Code [M4Y] category [Residence] venues dataframe shape: (46, 7)
# Found local data for M4Y-Shops
# Postal Code [M4Y] category [Shops] venues dataframe shape: (48, 7)
# Found local data for M4Y-Travel
# Postal Code [M4Y] category [Travel] venues dataframe shape: (32, 7)
# Found local data for M5A-Arts & Entertainment
# Postal Code [M5A] category [Arts & Entertainment] venues dataframe shape: (50, 7)
# Found local data for M5A-College & Education
# Postal Code [M5A] category [College & Education] venues dataframe shape: (8, 7)
# Found local data for M5A-Event
# Postal Code [M5A] category [Event] venues dataframe shape: (4, 7)
# Found local data for M5A-Food
# Postal Code [M5A] category [Food] venues dataframe shape: (46, 7)
# Found local data for M5A-Nightlife
# Postal Code [M5A] category [Nightlife] venues dataframe shape: (28, 7)
# Found local data for M5A-Outdoors & Recreation
# Postal Code [M5A] category [Outdoors & Recreation] venues dataframe shape: (44, 7)
# Found local data for M5A-Professional
# Postal Code [M5A] category [Professional] venues dataframe shape: (48, 7)
# Found local data for M5A-Residence
# Postal Code [M5A] category [Residence] venues dataframe shape: (37, 7)
# Found local data for M5A-Shops
# Postal Code [M5A] category [Shops] venues dataframe shape: (43, 7)
# Found local data for M5A-Travel
# Postal Code [M5A] category [Travel] venues dataframe shape: (33, 7)
# Found local data for M5B-Arts & Entertainment
# Postal Code [M5B] category [Arts & Entertainment] venues dataframe shape: (44, 7)
# Found local data for M5B-College & Education
# Postal Code [M5B] category [College & Education] venues dataframe shape: (46, 7)
# Found local data for M5B-Event
# Postal Code [M5B] category [Event] venues dataframe shape: (1, 7)
# Found local data for M5B-Food
# Postal Code [M5B] category [Food] venues dataframe shape: (50, 7)
# Found local data for M5B-Nightlife
# Postal Code [M5B] category [Nightlife] venues dataframe shape: (49, 7)
# Found local data for M5B-Outdoors & Recreation
# Postal Code [M5B] category [Outdoors & Recreation] venues dataframe shape: (45, 7)
# Found local data for M5B-Professional
# Postal Code [M5B] category [Professional] venues dataframe shape: (42, 7)
# Found local data for M5B-Residence
# Postal Code [M5B] category [Residence] venues dataframe shape: (44, 7)
# Found local data for M5B-Shops
# Postal Code [M5B] category [Shops] venues dataframe shape: (48, 7)
# Found local data for M5B-Travel
# Postal Code [M5B] category [Travel] venues dataframe shape: (36, 7)
# Found local data for M5C-Arts & Entertainment
# Postal Code [M5C] category [Arts & Entertainment] venues dataframe shape: (43, 7)
# Found local data for M5C-College & Education
# Postal Code [M5C] category [College & Education] venues dataframe shape: (49, 7)
# Found local data for M5C-Event
# Postal Code [M5C] category [Event] venues dataframe shape: (1, 7)
# Found local data for M5C-Food
# Postal Code [M5C] category [Food] venues dataframe shape: (50, 7)
# Found local data for M5C-Nightlife
# Postal Code [M5C] category [Nightlife] venues dataframe shape: (46, 7)
# Found local data for M5C-Outdoors & Recreation
# Postal Code [M5C] category [Outdoors & Recreation] venues dataframe shape: (44, 7)
# Found local data for M5C-Professional
# Postal Code [M5C] category [Professional] venues dataframe shape: (48, 7)
# Found local data for M5C-Residence
# Postal Code [M5C] category [Residence] venues dataframe shape: (36, 7)
# Found local data for M5C-Shops
# Postal Code [M5C] category [Shops] venues dataframe shape: (45, 7)
# Found local data for M5C-Travel
# Postal Code [M5C] category [Travel] venues dataframe shape: (33, 7)
# Found local data for M5E-Arts & Entertainment
# Postal Code [M5E] category [Arts & Entertainment] venues dataframe shape: (46, 7)
# Found local data for M5E-College & Education
# Postal Code [M5E] category [College & Education] venues dataframe shape: (12, 7)
# Found local data for M5E-Event
# Postal Code [M5E] category [Event] venues dataframe shape: (2, 7)
# Found local data for M5E-Food
# Postal Code [M5E] category [Food] venues dataframe shape: (49, 7)
# Found local data for M5E-Nightlife
# Postal Code [M5E] category [Nightlife] venues dataframe shape: (47, 7)
# Found local data for M5E-Outdoors & Recreation
# Postal Code [M5E] category [Outdoors & Recreation] venues dataframe shape: (42, 7)
# Found local data for M5E-Professional
# Postal Code [M5E] category [Professional] venues dataframe shape: (41, 7)
# Found local data for M5E-Residence
# Postal Code [M5E] category [Residence] venues dataframe shape: (45, 7)
# Found local data for M5E-Shops
# Postal Code [M5E] category [Shops] venues dataframe shape: (41, 7)
# Found local data for M5E-Travel
# Postal Code [M5E] category [Travel] venues dataframe shape: (36, 7)
# Found local data for M5G-Arts & Entertainment
# Postal Code [M5G] category [Arts & Entertainment] venues dataframe shape: (43, 7)
# Found local data for M5G-College & Education
# Postal Code [M5G] category [College & Education] venues dataframe shape: (48, 7)
# Found local data for M5G-Event
# Found local data for M5G-Food
# Postal Code [M5G] category [Food] venues dataframe shape: (50, 7)
# Found local data for M5G-Nightlife
# Postal Code [M5G] category [Nightlife] venues dataframe shape: (46, 7)
# Found local data for M5G-Outdoors & Recreation
# Postal Code [M5G] category [Outdoors & Recreation] venues dataframe shape: (43, 7)
# Found local data for M5G-Professional
# Postal Code [M5G] category [Professional] venues dataframe shape: (45, 7)
# Found local data for M5G-Residence
# Postal Code [M5G] category [Residence] venues dataframe shape: (47, 7)
# Found local data for M5G-Shops
# Postal Code [M5G] category [Shops] venues dataframe shape: (44, 7)
# Found local data for M5G-Travel
# Postal Code [M5G] category [Travel] venues dataframe shape: (31, 7)
# Found local data for M5H-Arts & Entertainment
# Postal Code [M5H] category [Arts & Entertainment] venues dataframe shape: (41, 7)
# Found local data for M5H-College & Education
# Postal Code [M5H] category [College & Education] venues dataframe shape: (43, 7)
# Found local data for M5H-Event
# Postal Code [M5H] category [Event] venues dataframe shape: (5, 7)
# Found local data for M5H-Food
# Postal Code [M5H] category [Food] venues dataframe shape: (50, 7)
# Found local data for M5H-Nightlife
# Postal Code [M5H] category [Nightlife] venues dataframe shape: (46, 7)
# Found local data for M5H-Outdoors & Recreation
# Postal Code [M5H] category [Outdoors & Recreation] venues dataframe shape: (42, 7)
# Found local data for M5H-Professional
# Postal Code [M5H] category [Professional] venues dataframe shape: (49, 7)
# Found local data for M5H-Residence
# Postal Code [M5H] category [Residence] venues dataframe shape: (43, 7)
# Found local data for M5H-Shops
# Postal Code [M5H] category [Shops] venues dataframe shape: (45, 7)
# Found local data for M5H-Travel
# Postal Code [M5H] category [Travel] venues dataframe shape: (31, 7)
# Found local data for M5J-Arts & Entertainment
# Postal Code [M5J] category [Arts & Entertainment] venues dataframe shape: (48, 7)
# Found local data for M5J-College & Education
# Postal Code [M5J] category [College & Education] venues dataframe shape: (11, 7)
# Found local data for M5J-Event
# Postal Code [M5J] category [Event] venues dataframe shape: (9, 7)
# Found local data for M5J-Food
# Postal Code [M5J] category [Food] venues dataframe shape: (50, 7)
# Found local data for M5J-Nightlife
# Postal Code [M5J] category [Nightlife] venues dataframe shape: (48, 7)
# Found local data for M5J-Outdoors & Recreation
# Postal Code [M5J] category [Outdoors & Recreation] venues dataframe shape: (47, 7)
# Found local data for M5J-Professional
# Postal Code [M5J] category [Professional] venues dataframe shape: (46, 7)
# Found local data for M5J-Residence
# Postal Code [M5J] category [Residence] venues dataframe shape: (47, 7)
# Found local data for M5J-Shops
# Postal Code [M5J] category [Shops] venues dataframe shape: (36, 7)
# Found local data for M5J-Travel
# Postal Code [M5J] category [Travel] venues dataframe shape: (36, 7)
# Found local data for M5K-Arts & Entertainment
# Postal Code [M5K] category [Arts & Entertainment] venues dataframe shape: (44, 7)
# Found local data for M5K-College & Education
# Postal Code [M5K] category [College & Education] venues dataframe shape: (38, 7)
# Found local data for M5K-Event
# Postal Code [M5K] category [Event] venues dataframe shape: (5, 7)
# Found local data for M5K-Food
# Postal Code [M5K] category [Food] venues dataframe shape: (50, 7)
# Found local data for M5K-Nightlife
# Postal Code [M5K] category [Nightlife] venues dataframe shape: (44, 7)
# Found local data for M5K-Outdoors & Recreation
# Postal Code [M5K] category [Outdoors & Recreation] venues dataframe shape: (46, 7)
# Found local data for M5K-Professional
# Postal Code [M5K] category [Professional] venues dataframe shape: (50, 7)
# Found local data for M5K-Residence
# Postal Code [M5K] category [Residence] venues dataframe shape: (41, 7)
# Found local data for M5K-Shops
# Postal Code [M5K] category [Shops] venues dataframe shape: (44, 7)
# Found local data for M5K-Travel
# Postal Code [M5K] category [Travel] venues dataframe shape: (34, 7)
# Found local data for M5L-Arts & Entertainment
# Postal Code [M5L] category [Arts & Entertainment] venues dataframe shape: (44, 7)
# Found local data for M5L-College & Education
# Postal Code [M5L] category [College & Education] venues dataframe shape: (37, 7)
# Found local data for M5L-Event
# Postal Code [M5L] category [Event] venues dataframe shape: (3, 7)
# Found local data for M5L-Food
# Postal Code [M5L] category [Food] venues dataframe shape: (50, 7)
# Found local data for M5L-Nightlife
# Postal Code [M5L] category [Nightlife] venues dataframe shape: (46, 7)
# Found local data for M5L-Outdoors & Recreation
# Postal Code [M5L] category [Outdoors & Recreation] venues dataframe shape: (46, 7)
# Found local data for M5L-Professional
# Postal Code [M5L] category [Professional] venues dataframe shape: (50, 7)
# Found local data for M5L-Residence
# Postal Code [M5L] category [Residence] venues dataframe shape: (39, 7)
# Found local data for M5L-Shops
# Postal Code [M5L] category [Shops] venues dataframe shape: (45, 7)
# Found local data for M5L-Travel
# Postal Code [M5L] category [Travel] venues dataframe shape: (36, 7)
# Found local data for M5N-Arts & Entertainment
# Found local data for M5N-College & Education
# Found local data for M5N-Event
# Found local data for M5N-Food
# Postal Code [M5N] category [Food] venues dataframe shape: (1, 7)
# Found local data for M5N-Nightlife
# Postal Code [M5N] category [Nightlife] venues dataframe shape: (2, 7)
# Found local data for M5N-Outdoors & Recreation
# Postal Code [M5N] category [Outdoors & Recreation] venues dataframe shape: (2, 7)
# Found local data for M5N-Professional
# Postal Code [M5N] category [Professional] venues dataframe shape: (5, 7)
# Found local data for M5N-Residence
# Found local data for M5N-Shops
# Postal Code [M5N] category [Shops] venues dataframe shape: (2, 7)
# Found local data for M5N-Travel
# Postal Code [M5N] category [Travel] venues dataframe shape: (2, 7)
# Found local data for M5P-Arts & Entertainment
# Found local data for M5P-College & Education
# Postal Code [M5P] category [College & Education] venues dataframe shape: (1, 7)
# Found local data for M5P-Event
# Found local data for M5P-Food
# Postal Code [M5P] category [Food] venues dataframe shape: (5, 7)
# Found local data for M5P-Nightlife
# Postal Code [M5P] category [Nightlife] venues dataframe shape: (2, 7)
# Found local data for M5P-Outdoors & Recreation
# Postal Code [M5P] category [Outdoors & Recreation] venues dataframe shape: (6, 7)
# Found local data for M5P-Professional
# Postal Code [M5P] category [Professional] venues dataframe shape: (8, 7)
# Found local data for M5P-Residence
# Postal Code [M5P] category [Residence] venues dataframe shape: (1, 7)
# Found local data for M5P-Shops
# Postal Code [M5P] category [Shops] venues dataframe shape: (4, 7)
# Found local data for M5P-Travel
# Postal Code [M5P] category [Travel] venues dataframe shape: (2, 7)
# Found local data for M5R-Arts & Entertainment
# Postal Code [M5R] category [Arts & Entertainment] venues dataframe shape: (23, 7)
# Found local data for M5R-College & Education
# Postal Code [M5R] category [College & Education] venues dataframe shape: (31, 7)
# Found local data for M5R-Event
# Found local data for M5R-Food
# Postal Code [M5R] category [Food] venues dataframe shape: (40, 7)
# Found local data for M5R-Nightlife
# Postal Code [M5R] category [Nightlife] venues dataframe shape: (23, 7)
# Found local data for M5R-Outdoors & Recreation
# Postal Code [M5R] category [Outdoors & Recreation] venues dataframe shape: (32, 7)
# Found local data for M5R-Professional
# Postal Code [M5R] category [Professional] venues dataframe shape: (41, 7)
# Found local data for M5R-Residence
# Postal Code [M5R] category [Residence] venues dataframe shape: (38, 7)
# Found local data for M5R-Shops
# Postal Code [M5R] category [Shops] venues dataframe shape: (40, 7)
# Found local data for M5R-Travel
# Postal Code [M5R] category [Travel] venues dataframe shape: (17, 7)
# Found local data for M5S-Arts & Entertainment
# Postal Code [M5S] category [Arts & Entertainment] venues dataframe shape: (48, 7)
# Found local data for M5S-College & Education
# Postal Code [M5S] category [College & Education] venues dataframe shape: (49, 7)
# Found local data for M5S-Event
# Found local data for M5S-Food
# Postal Code [M5S] category [Food] venues dataframe shape: (47, 7)
# Found local data for M5S-Nightlife
# Postal Code [M5S] category [Nightlife] venues dataframe shape: (28, 7)
# Found local data for M5S-Outdoors & Recreation
# Postal Code [M5S] category [Outdoors & Recreation] venues dataframe shape: (43, 7)
# Found local data for M5S-Professional
# Postal Code [M5S] category [Professional] venues dataframe shape: (40, 7)
# Found local data for M5S-Residence
# Postal Code [M5S] category [Residence] venues dataframe shape: (16, 7)
# Found local data for M5S-Shops
# Postal Code [M5S] category [Shops] venues dataframe shape: (39, 7)
# Found local data for M5S-Travel
# Postal Code [M5S] category [Travel] venues dataframe shape: (33, 7)
# Found local data for M5T-Arts & Entertainment
# Postal Code [M5T] category [Arts & Entertainment] venues dataframe shape: (47, 7)
# Found local data for M5T-College & Education
# Postal Code [M5T] category [College & Education] venues dataframe shape: (13, 7)
# Found local data for M5T-Event
# Found local data for M5T-Food
# Postal Code [M5T] category [Food] venues dataframe shape: (50, 7)
# Found local data for M5T-Nightlife
# Postal Code [M5T] category [Nightlife] venues dataframe shape: (47, 7)
# Found local data for M5T-Outdoors & Recreation
# Postal Code [M5T] category [Outdoors & Recreation] venues dataframe shape: (40, 7)
# Found local data for M5T-Professional
# Postal Code [M5T] category [Professional] venues dataframe shape: (47, 7)
# Found local data for M5T-Residence
# Postal Code [M5T] category [Residence] venues dataframe shape: (35, 7)
# Found local data for M5T-Shops
# Postal Code [M5T] category [Shops] venues dataframe shape: (46, 7)
# Found local data for M5T-Travel
# Postal Code [M5T] category [Travel] venues dataframe shape: (37, 7)
# Found local data for M5V-Arts & Entertainment
# Postal Code [M5V] category [Arts & Entertainment] venues dataframe shape: (3, 7)
# Found local data for M5V-College & Education
# Found local data for M5V-Event
# Found local data for M5V-Food
# Postal Code [M5V] category [Food] venues dataframe shape: (4, 7)
# Found local data for M5V-Nightlife
# Postal Code [M5V] category [Nightlife] venues dataframe shape: (1, 7)
# Found local data for M5V-Outdoors & Recreation
# Postal Code [M5V] category [Outdoors & Recreation] venues dataframe shape: (5, 7)
# Found local data for M5V-Professional
# Postal Code [M5V] category [Professional] venues dataframe shape: (4, 7)
# Found local data for M5V-Residence
# Found local data for M5V-Shops
# Postal Code [M5V] category [Shops] venues dataframe shape: (2, 7)
# Found local data for M5V-Travel
# Postal Code [M5V] category [Travel] venues dataframe shape: (23, 7)
# Found local data for M5W-Arts & Entertainment
# Postal Code [M5W] category [Arts & Entertainment] venues dataframe shape: (45, 7)
# Found local data for M5W-College & Education
# Postal Code [M5W] category [College & Education] venues dataframe shape: (24, 7)
# Found local data for M5W-Event
# Postal Code [M5W] category [Event] venues dataframe shape: (3, 7)
# Found local data for M5W-Food
# Postal Code [M5W] category [Food] venues dataframe shape: (50, 7)
# Found local data for M5W-Nightlife
# Postal Code [M5W] category [Nightlife] venues dataframe shape: (44, 7)
# Found local data for M5W-Outdoors & Recreation
# Postal Code [M5W] category [Outdoors & Recreation] venues dataframe shape: (43, 7)
# Found local data for M5W-Professional
# Postal Code [M5W] category [Professional] venues dataframe shape: (45, 7)
# Found local data for M5W-Residence
# Postal Code [M5W] category [Residence] venues dataframe shape: (42, 7)
# Found local data for M5W-Shops
# Postal Code [M5W] category [Shops] venues dataframe shape: (43, 7)
# Found local data for M5W-Travel
# Postal Code [M5W] category [Travel] venues dataframe shape: (34, 7)
# Found local data for M5X-Arts & Entertainment
# Postal Code [M5X] category [Arts & Entertainment] venues dataframe shape: (40, 7)
# Found local data for M5X-College & Education
# Postal Code [M5X] category [College & Education] venues dataframe shape: (39, 7)
# Found local data for M5X-Event
# Postal Code [M5X] category [Event] venues dataframe shape: (3, 7)
# Found local data for M5X-Food
# Postal Code [M5X] category [Food] venues dataframe shape: (50, 7)
# Found local data for M5X-Nightlife
# Postal Code [M5X] category [Nightlife] venues dataframe shape: (43, 7)
# Found local data for M5X-Outdoors & Recreation
# Postal Code [M5X] category [Outdoors & Recreation] venues dataframe shape: (44, 7)
# Found local data for M5X-Professional
# Postal Code [M5X] category [Professional] venues dataframe shape: (50, 7)
# Found local data for M5X-Residence
# Postal Code [M5X] category [Residence] venues dataframe shape: (38, 7)
# Found local data for M5X-Shops
# Postal Code [M5X] category [Shops] venues dataframe shape: (44, 7)
# Found local data for M5X-Travel
# Postal Code [M5X] category [Travel] venues dataframe shape: (34, 7)
# Found local data for M6G-Arts & Entertainment
# Postal Code [M6G] category [Arts & Entertainment] venues dataframe shape: (7, 7)
# Found local data for M6G-College & Education
# Postal Code [M6G] category [College & Education] venues dataframe shape: (2, 7)
# Found local data for M6G-Event
# Found local data for M6G-Food
# Postal Code [M6G] category [Food] venues dataframe shape: (27, 7)
# Found local data for M6G-Nightlife
# Postal Code [M6G] category [Nightlife] venues dataframe shape: (8, 7)
# Found local data for M6G-Outdoors & Recreation
# Postal Code [M6G] category [Outdoors & Recreation] venues dataframe shape: (15, 7)
# Found local data for M6G-Professional
# Postal Code [M6G] category [Professional] venues dataframe shape: (28, 7)
# Found local data for M6G-Residence
# Postal Code [M6G] category [Residence] venues dataframe shape: (7, 7)
# Found local data for M6G-Shops
# Postal Code [M6G] category [Shops] venues dataframe shape: (35, 7)
# Found local data for M6G-Travel
# Postal Code [M6G] category [Travel] venues dataframe shape: (8, 7)
# Found local data for M6H-Arts & Entertainment
# Postal Code [M6H] category [Arts & Entertainment] venues dataframe shape: (21, 7)
# Found local data for M6H-College & Education
# Postal Code [M6H] category [College & Education] venues dataframe shape: (6, 7)
# Found local data for M6H-Event
# Found local data for M6H-Food
# Postal Code [M6H] category [Food] venues dataframe shape: (31, 7)
# Found local data for M6H-Nightlife
# Postal Code [M6H] category [Nightlife] venues dataframe shape: (20, 7)
# Found local data for M6H-Outdoors & Recreation
# Postal Code [M6H] category [Outdoors & Recreation] venues dataframe shape: (33, 7)
# Found local data for M6H-Professional
# Postal Code [M6H] category [Professional] venues dataframe shape: (42, 7)
# Found local data for M6H-Residence
# Postal Code [M6H] category [Residence] venues dataframe shape: (13, 7)
# Found local data for M6H-Shops
# Postal Code [M6H] category [Shops] venues dataframe shape: (43, 7)
# Found local data for M6H-Travel
# Postal Code [M6H] category [Travel] venues dataframe shape: (15, 7)
# Found local data for M6J-Arts & Entertainment
# Postal Code [M6J] category [Arts & Entertainment] venues dataframe shape: (45, 7)
# Found local data for M6J-College & Education
# Postal Code [M6J] category [College & Education] venues dataframe shape: (6, 7)
# Found local data for M6J-Event
# Postal Code [M6J] category [Event] venues dataframe shape: (1, 7)
# Found local data for M6J-Food
# Postal Code [M6J] category [Food] venues dataframe shape: (48, 7)
# Found local data for M6J-Nightlife
# Postal Code [M6J] category [Nightlife] venues dataframe shape: (48, 7)
# Found local data for M6J-Outdoors & Recreation
# Postal Code [M6J] category [Outdoors & Recreation] venues dataframe shape: (41, 7)
# Found local data for M6J-Professional
# Postal Code [M6J] category [Professional] venues dataframe shape: (46, 7)
# Found local data for M6J-Residence
# Postal Code [M6J] category [Residence] venues dataframe shape: (15, 7)
# Found local data for M6J-Shops
# Postal Code [M6J] category [Shops] venues dataframe shape: (46, 7)
# Found local data for M6J-Travel
# Postal Code [M6J] category [Travel] venues dataframe shape: (28, 7)
# Found local data for M6K-Arts & Entertainment
# Postal Code [M6K] category [Arts & Entertainment] venues dataframe shape: (32, 7)
# Found local data for M6K-College & Education
# Postal Code [M6K] category [College & Education] venues dataframe shape: (4, 7)
# Found local data for M6K-Event
# Found local data for M6K-Food
# Postal Code [M6K] category [Food] venues dataframe shape: (50, 7)
# Found local data for M6K-Nightlife
# Postal Code [M6K] category [Nightlife] venues dataframe shape: (43, 7)
# Found local data for M6K-Outdoors & Recreation
# Postal Code [M6K] category [Outdoors & Recreation] venues dataframe shape: (36, 7)
# Found local data for M6K-Professional
# Postal Code [M6K] category [Professional] venues dataframe shape: (45, 7)
# Found local data for M6K-Residence
# Postal Code [M6K] category [Residence] venues dataframe shape: (42, 7)
# Found local data for M6K-Shops
# Postal Code [M6K] category [Shops] venues dataframe shape: (39, 7)
# Found local data for M6K-Travel
# Postal Code [M6K] category [Travel] venues dataframe shape: (14, 7)
# Found local data for M6P-Arts & Entertainment
# Postal Code [M6P] category [Arts & Entertainment] venues dataframe shape: (17, 7)
# Found local data for M6P-College & Education
# Postal Code [M6P] category [College & Education] venues dataframe shape: (5, 7)
# Found local data for M6P-Event
# Found local data for M6P-Food
# Postal Code [M6P] category [Food] venues dataframe shape: (46, 7)
# Found local data for M6P-Nightlife
# Postal Code [M6P] category [Nightlife] venues dataframe shape: (22, 7)
# Found local data for M6P-Outdoors & Recreation
# Postal Code [M6P] category [Outdoors & Recreation] venues dataframe shape: (12, 7)
# Found local data for M6P-Professional
# Postal Code [M6P] category [Professional] venues dataframe shape: (42, 7)
# Found local data for M6P-Residence
# Postal Code [M6P] category [Residence] venues dataframe shape: (9, 7)
# Found local data for M6P-Shops
# Postal Code [M6P] category [Shops] venues dataframe shape: (41, 7)
# Found local data for M6P-Travel
# Postal Code [M6P] category [Travel] venues dataframe shape: (10, 7)
# Found local data for M6R-Arts & Entertainment
# Postal Code [M6R] category [Arts & Entertainment] venues dataframe shape: (10, 7)
# Found local data for M6R-College & Education
# Found local data for M6R-Event
# Postal Code [M6R] category [Event] venues dataframe shape: (1, 7)
# Found local data for M6R-Food
# Postal Code [M6R] category [Food] venues dataframe shape: (44, 7)
# Found local data for M6R-Nightlife
# Postal Code [M6R] category [Nightlife] venues dataframe shape: (10, 7)
# Found local data for M6R-Outdoors & Recreation
# Postal Code [M6R] category [Outdoors & Recreation] venues dataframe shape: (10, 7)
# Found local data for M6R-Professional
# Postal Code [M6R] category [Professional] venues dataframe shape: (27, 7)
# Found local data for M6R-Residence
# Postal Code [M6R] category [Residence] venues dataframe shape: (3, 7)
# Found local data for M6R-Shops
# Postal Code [M6R] category [Shops] venues dataframe shape: (41, 7)
# Found local data for M6R-Travel
# Postal Code [M6R] category [Travel] venues dataframe shape: (8, 7)
# Found local data for M6S-Arts & Entertainment
# Postal Code [M6S] category [Arts & Entertainment] venues dataframe shape: (9, 7)
# Found local data for M6S-College & Education
# Found local data for M6S-Event
# Found local data for M6S-Food
# Postal Code [M6S] category [Food] venues dataframe shape: (48, 7)
# Found local data for M6S-Nightlife
# Postal Code [M6S] category [Nightlife] venues dataframe shape: (11, 7)
# Found local data for M6S-Outdoors & Recreation
# Postal Code [M6S] category [Outdoors & Recreation] venues dataframe shape: (17, 7)
# Found local data for M6S-Professional
# Postal Code [M6S] category [Professional] venues dataframe shape: (42, 7)
# Found local data for M6S-Residence
# Postal Code [M6S] category [Residence] venues dataframe shape: (4, 7)
# Found local data for M6S-Shops
# Postal Code [M6S] category [Shops] venues dataframe shape: (47, 7)
# Found local data for M6S-Travel
# Postal Code [M6S] category [Travel] venues dataframe shape: (5, 7)
# Found local data for M7A-Arts & Entertainment
# Postal Code [M7A] category [Arts & Entertainment] venues dataframe shape: (44, 7)
# Found local data for M7A-College & Education
# Postal Code [M7A] category [College & Education] venues dataframe shape: (48, 7)
# Found local data for M7A-Event
# Found local data for M7A-Food
# Postal Code [M7A] category [Food] venues dataframe shape: (48, 7)
# Found local data for M7A-Nightlife
# Postal Code [M7A] category [Nightlife] venues dataframe shape: (42, 7)
# Found local data for M7A-Outdoors & Recreation
# Postal Code [M7A] category [Outdoors & Recreation] venues dataframe shape: (41, 7)
# Found local data for M7A-Professional
# Postal Code [M7A] category [Professional] venues dataframe shape: (49, 7)
# Found local data for M7A-Residence
# Postal Code [M7A] category [Residence] venues dataframe shape: (48, 7)
# Found local data for M7A-Shops
# Postal Code [M7A] category [Shops] venues dataframe shape: (46, 7)
# Found local data for M7A-Travel
# Postal Code [M7A] category [Travel] venues dataframe shape: (29, 7)
# Found local data for M7Y-Arts & Entertainment
# Postal Code [M7Y] category [Arts & Entertainment] venues dataframe shape: (8, 7)
# Found local data for M7Y-College & Education
# Found local data for M7Y-Event
# Found local data for M7Y-Food
# Postal Code [M7Y] category [Food] venues dataframe shape: (36, 7)
# Found local data for M7Y-Nightlife
# Postal Code [M7Y] category [Nightlife] venues dataframe shape: (5, 7)
# Found local data for M7Y-Outdoors & Recreation
# Postal Code [M7Y] category [Outdoors & Recreation] venues dataframe shape: (16, 7)
# Found local data for M7Y-Professional
# Postal Code [M7Y] category [Professional] venues dataframe shape: (33, 7)
# Found local data for M7Y-Residence
# Postal Code [M7Y] category [Residence] venues dataframe shape: (4, 7)
# Found local data for M7Y-Shops
# Postal Code [M7Y] category [Shops] venues dataframe shape: (46, 7)
# Found local data for M7Y-Travel
# Postal Code [M7Y] category [Travel] venues dataframe shape: (14, 7)
# (9732, 7)
#   neighborhoods postcode         main category                          name  \
# 0   The Beaches      M4E  Arts & Entertainment                    Studio 888
# 1   The Beaches      M4E  Arts & Entertainment  Toronto Theatre Dance School
# 2   The Beaches      M4E  Arts & Entertainment                  Lens Factory
# 3   The Beaches      M4E  Arts & Entertainment  Beaches Dance & Music Studio
# 4   The Beaches      M4E  Arts & Entertainment         St-Denis Studios Inc.
#
#          lat        lng                                         categories
# 0  43.672264 -79.288910  [{'id': '4bf58dd8d48988d1e2931735', 'name': 'A...
# 1  43.680833 -79.291376  [{'id': '4bf58dd8d48988d134941735', 'name': 'D...
# 2  43.671987 -79.290421  [{'id': '4bf58dd8d48988d1e2931735', 'name': 'A...
# 3  43.680595 -79.291300  [{'id': '4bf58dd8d48988d134941735', 'name': 'D...
# 4  43.675031 -79.288022  [{'id': '4bf58dd8d48988d1e5931735', 'name': 'M...

# %% [markdown]
# **Simplifying venue categories.**

# %%
from numpy import NaN

for i, row in df_venues.iterrows():
    cats = row['categories']
    if isinstance(cats, list):
        if len(cats) > 0:
            df_venues.loc[i, 'categories'] = cats[0]['name']
        else:
            df_venues.loc[i, 'categories'] = NaN

df_venues.head()
# Out:
#   neighborhoods postcode         main category                          name  \
# 0   The Beaches      M4E  Arts & Entertainment                    Studio 888
# 1   The Beaches      M4E  Arts & Entertainment  Toronto Theatre Dance School
# 2   The Beaches      M4E  Arts & Entertainment                  Lens Factory
# 3   The Beaches      M4E  Arts & Entertainment  Beaches Dance & Music Studio
# 4   The Beaches      M4E  Arts & Entertainment         St-Denis Studios Inc.
#
#          lat        lng    categories
# 0  43.672264 -79.288910   Art Gallery
# 1  43.680833 -79.291376  Dance Studio
# 2  43.671987 -79.290421   Art Gallery
# 3  43.680595 -79.291300  Dance Studio
# 4  43.675031 -79.288022   Music Venue

# %% [markdown]
# **One-hot encode venue categories, and group by postal code.**

# %%
df_onehot = pd.get_dummies(df_venues[['main category']], prefix='', prefix_sep='')
df_onehot['postcode'] = df_venues['postcode']
df_grouped = df_onehot.groupby('postcode').mean().reset_index()

df_grouped.head()
# Out:
#   postcode  Arts & Entertainment  College & Education     Event      Food  \
# 0      M4E              0.033784             0.027027  0.000000  0.256757
# 1      M4K              0.077551             0.012245  0.000000  0.200000
# 2      M4L              0.090426             0.010638  0.000000  0.244681
# 3      M4M              0.120755             0.003774  0.003774  0.184906
# 4      M4N              0.115385             0.153846  0.000000  0.038462
#
#    Nightlife  Outdoors & Recreation  Professional  Residence     Shops  \
# 0   0.047297               0.128378      0.182432   0.033784  0.263514
# 1   0.126531               0.175510      0.163265   0.028571  0.171429
# 2   0.058511               0.111702      0.159574   0.015957  0.244681
# 3   0.094340               0.158491      0.181132   0.022642  0.154717
# 4   0.000000               0.153846      0.307692   0.038462  0.153846
#
#      Travel
# 0  0.027027
# 1  0.044898
# 2  0.063830
# 3  0.075472
# 4  0.038462

# %% [markdown]
# **Clustering neighborhoods**

# %%
from sklearn.cluster import KMeans

kclusters = 5

df_clustering = df_grouped.drop('postcode', 1)
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(df_clustering)

df_clustered = df_geo[:]
df_clustered.insert(0, 'Cluster Labels', kmeans.labels_)
df_clustered.head()
# Out:
#    Cluster Labels Postal Code          Borough  \
# 0               0         M4E     East Toronto
# 1               4         M4K     East Toronto
# 2               0         M4L     East Toronto
# 3               4         M4M     East Toronto
# 4               2         M4N  Central Toronto
#
#                      Neighborhood   Latitude  Longitude
# 0                     The Beaches  43.676357 -79.293031
# 1    The Danforth West, Riverdale  43.679557 -79.352188
# 2  India Bazaar, The Beaches West  43.668999 -79.315572
# 3                 Studio District  43.659526 -79.340923
# 4                   Lawrence Park  43.728020 -79.388790

# %% [markdown]
# **Drawing a map to illustrate clustering result.**

# %%
import numpy as np
from matplotlib import cm
from matplotlib import colors

map_clusters = folium.Map(location=[loc.latitude, loc.longitude], zoom_start=11)

x = np.arange(kclusters)
ys = [i+x+(i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, kclusters))
rainbow = [colors.rgb2hex(i) for i in colors_array]

for postcode, lat, lng, poi, cluster in zip(df_clustered['Postal Code'], df_clustered['Latitude'], df_clustered['Longitude'], df_clustered['Neighborhood'], df_clustered['Cluster Labels']):
    label = folium.Popup('{} - {} - Cluster {}'.format(postcode, poi, cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius = 5,
        popup = label,
        color = rainbow[cluster],
        fill = True,
        fill_color = rainbow[cluster],
        fill_opacity = 0.7
    ).add_to(map_clusters)

map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# **Observations.**

# %%
num_top_values = 5

indicators = ['st', 'nd', 'rd', 'th']
columns = ['Postal Code', 'Neighborhoods']
for x in range(num_top_values):
    columns.append('{}{} Most Common Venue'.format(x+1, indicators[min(len(indicators)-1, x)]))

def get_most_common(postcode):
    return df_grouped[df_grouped['postcode']==postcode].reset_index(drop=True).T.iloc[1:].sort_values(by=0, ascending=False).index.values[0:num_top_values]

# %% [markdown]
# **Cluster 0**
#
# As can be seen below, Cluster 0 areas consist primarily of shops and eateries.

# %%
df_0 = pd.DataFrame(columns=columns)
df_0['Postal Code'] = df_clustered[df_clustered['Cluster Labels']==0]['Postal Code']
df_0['Neighborhoods'] = df_clustered[df_clustered['Cluster Labels']==0]['Neighborhood']
df_0 = df_0.reset_index(drop = True)

for i, row in df_0.iterrows():
    most_common = get_most_common(df_0.loc[i, 'Postal Code'])
    for j in range(2, 2 + num_top_values):
        df_0.iloc[i, j] = most_common[j - 2]

df_0
# Out:
#   Postal Code                                      Neighborhoods  \
# 0         M4E                                        The Beaches
# 1         M4L                     India Bazaar, The Beaches West
# 2         M4R                 North Toronto West,  Lawrence Park
# 3         M6G                                           Christie
# 4         M6P                      High Park, The Junction South
# 5         M6R                             Parkdale, Roncesvalles
# 6         M6S                                 Runnymede, Swansea
# 7         M7Y  Business reply mail Processing Centre, South C...
#
#   1st Most Common Venue 2nd Most Common Venue 3rd Most Common Venue  \
# 0                 Shops                  Food          Professional
# 1                  Food                 Shops          Professional
# 2                 Shops                  Food          Professional
# 3                 Shops          Professional                  Food
# 4                  Food          Professional                 Shops
# 5                  Food                 Shops          Professional
# 6                  Food                 Shops          Professional
# 7                 Shops                  Food          Professional
#
#    4th Most Common Venue 5th Most Common Venue
# 0  Outdoors & Recreation             Nightlife
# 1  Outdoors & Recreation  Arts & Entertainment
# 2  Outdoors & Recreation  Arts & Entertainment
# 3  Outdoors & Recreation             Nightlife
# 4              Nightlife  Arts & Entertainment
# 5   Arts & Entertainment             Nightlife
# 6  Outdoors & Recreation             Nightlife
# 7  Outdoors & Recreation                Travel

# %% [markdown]
# **Cluster 1**
#
# Areas in Cluster 1 appear to form an entertainment district, with primarily food-related and Arts & Entertainment venues.

# %%
df_1 = pd.DataFrame(columns=columns)
df_1['Postal Code'] = df_clustered[df_clustered['Cluster Labels']==1]['Postal Code']
df_1['Neighborhoods'] = df_clustered[df_clustered['Cluster Labels']==1]['Neighborhood']
df_1 = df_1.reset_index(drop = True)

for i, row in df_1.iterrows():
    most_common = get_most_common(df_1.loc[i, 'Postal Code'])
    for j in range(2, 2 + num_top_values):
        df_1.iloc[i, j] = most_common[j - 2]

df_1
# Out:
#    Postal Code                                      Neighborhoods  \
# 0          M4Y                               Church and Wellesley
# 1          M5A                          Regent Park, Harbourfront
# 2          M5B                           Garden District, Ryerson
# 3          M5C                                     St. James Town
# 4          M5E                                        Berczy Park
# 5          M5G                                 Central Bay Street
# 6          M5H                           Richmond, Adelaide, King
# 7          M5J  Harbourfront East, Union Station, Toronto Islands
# 8          M5K           Toronto Dominion Centre, Design Exchange
# 9          M5L                     Commerce Court, Victoria Hotel
# 10         M5R                The Annex, North Midtown, Yorkville
# 11         M5S                     University of Toronto, Harbord
# 12         M5T          Kensington Market, Chinatown, Grange Park
# 13         M5W                                     Stn A PO Boxes
# 14         M5X             First Canadian Place, Underground city
# 15         M6J                           Little Portugal, Trinity
# 16         M7A        Queen's Park, Ontario Provincial Government
#
#    1st Most Common Venue 2nd Most Common Venue  3rd Most Common Venue  \
# 0                   Food                 Shops              Nightlife
# 1   Arts & Entertainment          Professional                   Food
# 2                   Food             Nightlife                  Shops
# 3                   Food   College & Education           Professional
# 4                   Food             Nightlife   Arts & Entertainment
# 5                   Food   College & Education              Residence
# 6                   Food          Professional              Nightlife
# 7                   Food  Arts & Entertainment              Nightlife
# 8                   Food          Professional  Outdoors & Recreation
# 9                   Food          Professional              Nightlife
# 10          Professional                  Food                  Shops
# 11   College & Education  Arts & Entertainment                   Food
# 12                  Food  Arts & Entertainment              Nightlife
# 13                  Food  Arts & Entertainment           Professional
# 14                  Food          Professional  Outdoors & Recreation
# 15                  Food             Nightlife           Professional
# 16          Professional   College & Education                   Food
#
#     4th Most Common Venue  5th Most Common Venue
# 0               Residence    College & Education
# 1   Outdoors & Recreation                  Shops
# 2     College & Education  Outdoors & Recreation
# 3               Nightlife                  Shops
# 4               Residence  Outdoors & Recreation
# 5               Nightlife           Professional
# 6                   Shops    College & Education
# 7   Outdoors & Recreation              Residence
# 8    Arts & Entertainment              Nightlife
# 9   Outdoors & Recreation                  Shops
# 10              Residence  Outdoors & Recreation
# 11  Outdoors & Recreation           Professional
# 12           Professional                  Shops
# 13              Nightlife  Outdoors & Recreation
# 14                  Shops              Nightlife
# 15                  Shops   Arts & Entertainment
# 16              Residence                  Shops

# %% [markdown]
# **Cluster 2**
#
# There is a good chance areas in this cluster are peaceful, with offices, parks and institutes dominating the venues list.

# %%
df_2 = pd.DataFrame(columns=columns)
df_2['Postal Code'] = df_clustered[df_clustered['Cluster Labels']==2]['Postal Code']
df_2['Neighborhoods'] = df_clustered[df_clustered['Cluster Labels']==2]['Neighborhood']
df_2 = df_2.reset_index(drop = True)


for i, row in df_2.iterrows():
    most_common = get_most_common(df_2.loc[i, 'Postal Code'])
    for j in range(2, 2 + num_top_values):
        df_2.iloc[i, j] = most_common[j - 2]

df_2
# Out:
#   Postal Code                                    Neighborhoods  \
# 0         M4N                                    Lawrence Park
# 1         M4T                      Moore Park, Summerhill East
# 2         M4W                                         Rosedale
# 3         M5N                                         Roselawn
# 4         M5P  Forest Hill North & West, Forest Hill Road Park
#
#    1st Most Common Venue  2nd Most Common Venue  3rd Most Common Venue  \
# 0           Professional    College & Education  Outdoors & Recreation
# 1  Outdoors & Recreation           Professional                   Food
# 2  Outdoors & Recreation           Professional              Residence
# 3           Professional              Nightlife  Outdoors & Recreation
# 4           Professional  Outdoors & Recreation                   Food
#
#   4th Most Common Venue 5th Most Common Venue
# 0                 Shops  Arts & Entertainment
# 1                 Shops  Arts & Entertainment
# 2                 Shops                Travel
# 3                 Shops                Travel
# 4                 Shops             Nightlife

# %% [markdown]
# **Cluster 3**
#
# This cluster appears to be an outlier, containing only one Postal Code. From the map, we can tell it accomodates the only airport in the wider area, which explains it's uniqueness to the surrounding Postal Codes.

# %%
df_3 = pd.DataFrame(columns=columns)
df_3['Postal Code'] = df_clustered[df_clustered['Cluster Labels']==3]['Postal Code']
df_3['Neighborhoods'] = df_clustered[df_clustered['Cluster Labels']==3]['Neighborhood']
df_3 = df_3.reset_index(drop = True)


for i, row in df_3.iterrows():
    most_common = get_most_common(df_3.loc[i, 'Postal Code'])
    for j in range(2, 2 + num_top_values):
        df_3.iloc[i, j] = most_common[j - 2]

df_3
# Out:
#   Postal Code                                      Neighborhoods  \
# 0         M5V  CN Tower, King and Spadina, Railway Lands, Har...
#
#   1st Most Common Venue  2nd Most Common Venue 3rd Most Common Venue  \
# 0                Travel  Outdoors & Recreation                  Food
#
#   4th Most Common Venue 5th Most Common Venue
# 0          Professional  Arts & Entertainment

# %% [markdown]
# **Cluster 4**
#
# Areas in Cluster 4 appear to be geared towards corporate offices, with Professional and Food related venues topping the list.

# %%
df_4 = pd.DataFrame(columns=columns)
df_4['Postal Code'] = df_clustered[df_clustered['Cluster Labels']==4]['Postal Code']
df_4['Neighborhoods'] = df_clustered[df_clustered['Cluster Labels']==4]['Neighborhood']
df_4 = df_4.reset_index(drop = True)


for i, row in df_4.iterrows():
    most_common = get_most_common(df_4.loc[i, 'Postal Code'])
    for j in range(2, 2 + num_top_values):
        df_4.iloc[i, j] = most_common[j - 2]

df_4
# Out:
#   Postal Code                                      Neighborhoods  \
# 0         M4K                       The Danforth West, Riverdale
# 1         M4M                                    Studio District
# 2         M4P                                   Davisville North
# 3         M4S                                         Davisville
# 4         M4V  Summerhill West, Rathnelly, South Hill, Forest...
# 5         M4X                        St. James Town, Cabbagetown
# 6         M6H                       Dufferin, Dovercourt Village
# 7         M6K       Brockton, Parkdale Village, Exhibition Place
#
#   1st Most Common Venue  2nd Most Common Venue  3rd Most Common Venue  \
# 0                  Food  Outdoors & Recreation                  Shops
# 1                  Food           Professional  Outdoors & Recreation
# 2             Residence           Professional                  Shops
# 3                  Food           Professional                  Shops
# 4                  Food           Professional              Residence
# 5                  Food                  Shops           Professional
# 6                 Shops           Professional  Outdoors & Recreation
# 7                  Food           Professional              Nightlife
#
#    4th Most Common Venue  5th Most Common Venue
# 0           Professional              Nightlife
# 1                  Shops   Arts & Entertainment
# 2  Outdoors & Recreation                   Food
# 3  Outdoors & Recreation              Residence
# 4                  Shops  Outdoors & Recreation
# 5              Residence  Outdoors & Recreation
# 6                   Food   Arts & Entertainment
# 7              Residence                  Shops
